# %% [markdown]
# <a href="https://colab.research.google.com/github/sajalgoyal007/Machine-Learning/blob/main/Machine_Learning_Part4/PCADimensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
